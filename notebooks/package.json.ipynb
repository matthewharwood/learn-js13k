// %% [markdown]
// # Package.json

// %% [markdown]
// # Whats inside?
//
//
// `archiver`
//
// - *Build time*
// - https://www.npmjs.com/package/archiver
// - Creates a zip or tar.gz file from a node stream. Comes with great events to append to a .zip file in real time based on stream output
//
//
// `cheerio`
//
// - *Build time*
// - Used to query dom `const _ = cheerio.load("<div>...</div>");`
// - Used in the zip.js to to query html and to minify the html.
//
//
// `eslint`
//
// - *Dev time*
// - used to link during dev time
//
// `eslint-config-prettier
//
// - *Dev Time*
// - Will auto fix indentation based off prettier file.
//
// `fast-xml-parser`
// - *Build time*
// - Will parse the levelX.tmx
// - **NEED more research**
//
// `fernandez-polygon-decomposition`
// - **NEED MROE RESEARCH**
// - https://www.npmjs.com/package/fernandez-polygon-decomposition
//
// `html-minifier`
// - *Build time*
// - Minifys html `scripts/libs/minifyHtml.js`
//
//
// `mkdirp`
// - *build time*
// - Makes a directory during zip.js
// - will output to `winner/build` by calling `npm run build`
//
// `prettier`
// - *dev time*
// - Will auto syntaxcorrect your code
//
// `prettysize`
// - *dev time*
// - Will out put package size
//
// `csso`
// - *build time*
// - will optimize css run during `npm run build`
//
// `terser`
//
// - *build time*
// - will optimize JS. Run during `npm run build`

// %% [markdown]
// ## Scripts
//
// #### **`npm run levels`**
//
// Will build levels using `./levels-compiler`
//
//
// #### how it works
// `./levels-compiler` will read and parse tmx files inside `root/levels/level#{x}.tmx` and generate a file `root/src/levels.js`.
//
// ##### levels struct:
//
// ```
// type Vec = {x: number, y: number};
// type Wall = Vec[];
// type Door = {name: string, polygon: Vec[], open: boolean};
// type Switch = {
//   uid: number,
//   x: number,
//   y: number,
//   targets: string[],
//   type: 'momentary' | 'single',
//   pressed: number
// }
//
// type Level {
//     id: number,
//     walls: Wall[],
//     polys: Poly[],
//     doors: Door[],
//     switches?: Switch[],
//     start?: Vec,
//     end?: Vec,
//     last?: number,
// }
// ```
//
//
// #### **`npm run zip`**
//
// Will create the final bundle for production.
//
// The Output will be generated at `root/out/` and it will make 2 files `index.html` and `out.zip`
//
// The first 2 rules
//
// > Package size below 13 kB
// All your code and game assets should be smaller than or equal to 13 kilobytes (that's exactly 13,312 bytes, because of 13 x 1024) when zipped. Your .zip package should contain index.html file in the top level folder structure (not a subfolder) and when unzipped should work in the browser. Don't overcomplicate building the zip package, it should unpack on any platform without problems. You can use tools that minify JavaScript source code.
//
// > Two sources - readable and compressed
// The competition is focusing on the package size, but learning from others is also very important. Please provide two sources of your game - first one should be minified and zipped to fit in the 13 kB limit (sent via the form) and the second one should be in a readable form with descriptive variable names and comments (hosted on GitHub).
